# %% [markdown]
# # codigo donde solicito los datos , inicio de desarrollo del proyecto

# %%
print("Bienvenido a la pagina de citas para los servivcios de sephora")
nombre = input("Ingresa tu nombre:")
fecha = input("Ingresa la fecha de la cita (DD/MM/AAAA)")
hora = float(input("Ingresa la hora de tu cita:"))
servicio = input("¿Que tipo de maquillaje deseas?")
marca = input("¿Que marca de maquillaje deseas?")

print("\n Datos de la cita")
print("Nombre:", nombre)
print("Fecha:", fecha)
print("Hora:", hora)
print("Tipo de servicio:", servicio)
print("Cita añadida.")
# Out:
# Bienvenido a la pagina de citas para los servivcios de sephora
#
#  Datos de la cita
# Nombre: soso
# Fecha: 22 de enero del 2027
# Hora: 14.03
# Tipo de servicio: maquillaje para novia
# Cita añadida.

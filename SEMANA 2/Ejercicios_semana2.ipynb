# %% [markdown]
# # ejercicios semana 2

# %%
edad = 22
if edad >= 18:
    print("Eres mayor de edad")
    print("Y ademas puedes votar")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad
# Y ademas puedes votar

# %%
calificacion = 65
if calificacion >=90:
    print ("A")
elif calificacion >=80:
    print("B")
elif calificacion >=70:
    print("C")
elif calificacion >=60:
    print("D")
else:
    print("E")
# Out:
# D

# %%
PL1 = True
PL2 = False

print(PL1 and PL2)
# Out:
# False

# %%
edad = 67
tipo = "adulto_mayor"
eres_mayor = edad >= 18
print(eres_mayor)
aplica_descuento = (edad >=60) and (tipo == "adulto_mayor")
print(aplica_descuento)
# Out:
# True
# False

# %%
edad = int(input("Ingresa tu edad: "))
if not ( edad < 0):
    print ("Aguanta, no hay edades menores a 0")
else:
    print("Ahora si vamos atrabajar con edades reales")
# Out:
# Aguanta, no hay edades menores a 0

# %%
precio = 599
if tipo == "adulto_mayor":
    descuento = precio * 0.12     

elif tipo == "profesor" or tipo == "estudiante":
    descuento = precio * 0.10

else:
    descuento = 0 
total = precio - descuento
print(f"Total a pagar : ${total:.2f}")
# Out:
# Total a pagar : $527.12

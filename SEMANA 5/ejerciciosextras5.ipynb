# %% [markdown]
# # Ejercicios extras 5

# %% [markdown]
# - Extra 1 Sistema de calificaciones con tuplas

# %%
def sumar_calificaciones(calificaciones):
    total = 0

    for calificacion in calificaciones:
        total += calificacion

    return total


calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)

print("Tercera calificación:", calificaciones[2])

nueva_calificacion1 = float(input("Nueva calificación 1: "))
nueva_calificacion2 = float(input("Nueva calificación 2: "))

nueva_tupla = calificaciones + (
    nueva_calificacion1,
    nueva_calificacion2
)

print("Nueva tupla:", nueva_tupla)

lista_ordenada = list(nueva_tupla)
lista_ordenada.sort(reverse=True)

print("Lista ordenada (mayor a menor):", lista_ordenada)

suma_total = sumar_calificaciones(nueva_tupla)

print("Suma total:", suma_total)
# Out:
# Tercera calificación: 8.0
# Nueva tupla: (7.5, 9.0, 8.0, 6.5, 10.0, 6.0, 9.0)
# Lista ordenada (mayor a menor): [10.0, 9.0, 9.0, 8.0, 7.5, 6.5, 6.0]
# Suma total: 56.0

# %% [markdown]
# - Ejercicio 2. Agenda de contactos con busqueda

# %%
def buscar_telefono(agenda, nombre):
    return agenda.get(nombre)


agenda = {
    "antonio": "5612054122",
    "lulis": "52986452",
    "william": "521736191"
}

nombre_nuevo = input("Nombre del nuevo contacto: ")
telefono_nuevo = input("Teléfono del nuevo contacto: ")

agenda[nombre_nuevo] = telefono_nuevo

print("Contactos registrados:", ", ".join(agenda.keys()))

nombre_buscado = input("Nombre a buscar: ")

telefono = buscar_telefono(agenda, nombre_buscado)

if telefono is not None:
    print(f"El teléfono de {nombre_buscado} es: {telefono}")
else:
    print("Contacto no encontrado.")
# Out:
# Contactos registrados: antonio, lulis, william, emi
# El teléfono de lulis es: 52986452

# %% [markdown]
# - Extra 3.Calculadora segura con excepciones

# %%
try:
    numero1 = int(input("Primer número entero: "))
    numero2 = int(input("Segundo número entero: "))

    resultado = numero1 / numero2

    print(f"{numero1} dividido entre {numero2} es: {resultado}")

except ValueError:
    print("Error: Debes ingresar números enteros.")

except ZeroDivisionError:
    print(
        "Error: No es posible dividir entre cero. "
        "Ingresa un divisor distinto de 0."
    )
# Out:
# 42 dividido entre 6 es: 7.0

# %% [markdown]
# - Extra 4.Analizador de mensajes con strings

# %%
def contar_palabras(texto):
    palabras = texto.split()
    return len(palabras)


mensaje = "Taylor swift es la mejor cantante de todos los tiempos"

print("Longitud del mensaje:", len(mensaje))
print("En mayúsculas:", mensaje.upper())

texto_reemplazado = mensaje.replace("Taylor swift", "North west")
print("Texto reemplazado:", texto_reemplazado)

total_palabras = contar_palabras(mensaje)
print("Palabras totales:", total_palabras)
# Out:
# Longitud del mensaje: 54
# En mayúsculas: TAYLOR SWIFT ES LA MEJOR CANTANTE DE TODOS LOS TIEMPOS
# Texto reemplazado: North west es la mejor cantante de todos los tiempos
# Palabras totales: 10

# %% [markdown]
# - EXTRA C 1.

# %% [markdown]
# - EXTRA C 2.

# %%
votos = {
    "Rojo": 0,
    "Azul": 0,
    "Verde": 0
}

cantidad_votos = 0

while cantidad_votos < 5:
    color = input("Ingresa tu voto (Rojo, Azul o Verde): ").capitalize()

    if color in votos:
        votos[color] += 1
        cantidad_votos += 1
    else:
        print("Color inválido. Inténtalo nuevamente.")

print("\nResultados:")

for color, total in votos.items():
    print(f"{color}: {total} votos")

mayor_cantidad = max(votos.values())

ganadores = []

for color, total in votos.items():
    if total == mayor_cantidad:
        ganadores.append(color)

if len(ganadores) == 1:
    print(
        f"El color ganador es {ganadores[0]} "
        f"con {mayor_cantidad} votos."
    )
else:
    print(
        f"Hay un empate entre {', '.join(ganadores)} "
        f"con {mayor_cantidad} votos cada uno."
    )
# Out:
# Resultados:
# Rojo: 1 votos
# Azul: 2 votos
# Verde: 2 votos
# Hay un empate entre Azul, Verde con 2 votos cada uno.

# %% [markdown]
# - EXTRA C 3.

# %%
while True:
    try:
        numero1 = int(input("Ingresa el primer número entero: "))
        numero2 = int(input("Ingresa el segundo número entero: "))
        break

    except ValueError:
        print(
            "Error: Debes ingresar números enteros. "
            "Inténtalo nuevamente."
        )

try:
    resultado = numero1 / numero2

    print(f"{numero1} dividido entre {numero2} es: {resultado}")

except ZeroDivisionError:
    print(
        "Error: No es posible dividir entre cero. "
        "El segundo número debe ser diferente de 0."
    )
# Out:
# 12 dividido entre 12 es: 1.0

# %% [markdown]
# - EXTRA C 4.

# %%
def contar_palabras(texto):
    palabras = texto.split()
    return len(palabras)


frase = input("Ingresa una frase que contenga la palabra Python: ")

print("Longitud de la frase:", len(frase))
print("Frase en mayúsculas:", frase.upper())

frase_reemplazada = frase.replace("Python", "programación")

print("Frase reemplazada:", frase_reemplazada)
print("Cantidad de palabras:", contar_palabras(frase))
# Out:
# Longitud de la frase: 18
# Frase en mayúsculas: PYTHON DONDE ESTAS
# Frase reemplazada: programación donde estas
# Cantidad de palabras: 3

# %% [markdown]
# - EXTRA C 5.

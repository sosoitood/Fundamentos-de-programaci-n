# %% [markdown]
# # Actividad 5.

# %%
def sumar_tupla(tupla):
    total = 0
    for numero in tupla:
        total += numero
    return total

def seccion_tuplas( ):
    print("\nSección de tuplas")
    numeros = (100,200,300,400,500)
    print("Tupla de números:", numeros)
    print("Tercer elemento:", numeros[2])
    
    try:
        e1 = float(input("Ingrese el primer número adicional: "))
        e2 = float(input("Ingrese el segundo número adicional: "))
    except ValueError:
        print("Error: Debe ingresar un número válido.")
        return  
    nueva_tupla = numeros + (e1, e2)
    print("Nueva tupla:", nueva_tupla)

    lista_ordenada = list(nueva_tupla)
    lista_ordenada.sort()
    print("Lista ordenada:", lista_ordenada)
    print("Suma de los elementos de la tupla:", sumar_tupla(nueva_tupla))

def buscar_telefono(contactos, nombre):
    return contactos.get(nombre)

def seccion_diccionario():
    print("\nSección de diccionarios")
    contactos = {
        "emiliano": "5612073746",
        "ariana": "5567841235",
        "ofelia": "58641326789"
    }
    nombre_nuevo = input("Ingrese el nombre del nuevo contacto: ")
    telefono_nuevo = input("Ingrese el número de teléfono del nuevo contacto: ")
    contactos[nombre_nuevo] = telefono_nuevo
    print("\nNombres de los contactos registrados:")
    for nombre in contactos.keys():
        print(nombre)
    nombre_buscado = input("\nIngrese el nombre del contacto a buscar: ")
    telefono_encontrado = buscar_telefono(contactos, nombre_buscado)   
    if telefono_encontrado is not None:
        print(f"El número de teléfono de {nombre_buscado} es: {telefono_encontrado}")
    else:
        print(f"No se encontró el contacto con el nombre {nombre_buscado}.")

def seccion_excepciones():
    print("\nSección de excepciones")
    try:
        n1 = int(input("Ingrese el primer numero entero: "))
        n2 = int(input("Ingrese el segundo numero entero: "))
        print("suma:", n1 + n2)
        print("division:", n1/n2)
    except ValueError:
        print("Error: Debe ingresar un número entero válido.")
    except ZeroDivisionError:
        print("Error: No se puede dividir entre cero.")

def seccion_strings():
    print("\nSección de strings")
    contar_palabras = lambda texto: len(texto.split())
    texto = input("Ingrese un texto: ")
    print("Texto ingresado:", texto)
    print("Longitud del texto:", len(texto))
    print("Texto en mayúsculas:", texto.upper())
    print("Cantidad de palabras:", contar_palabras(texto))

while True:
    print("\nMenú de opciones:")
    print("1. Sección de tuplas")
    print("2. Sección de diccionarios")
    print("3. Sección de excepciones")
    print("4. Sección de strings")
    print("5. Salir")
    opcion = input("Seleccione una opción (1-5): ")
    if opcion == "1":
        seccion_tuplas()
    elif opcion == "2":
        seccion_diccionario()
    elif opcion == "3":
        seccion_excepciones()
    elif opcion == "4":
        seccion_strings()
    elif opcion == "5":
        break
    else:
        print("Opción inválida. Por favor, seleccione una opción válida.")
# Out:
# Menú de opciones:
# 1. Sección de tuplas
# 2. Sección de diccionarios
# 3. Sección de excepciones
# 4. Sección de strings
# 5. Salir
#
# Sección de tuplas
# Tupla de números: (100, 200, 300, 400, 500)
# Tercer elemento: 300
# Nueva tupla: (100, 200, 300, 400, 500, 5.0, 8.0)
# Lista ordenada: [5.0, 8.0, 100, 200, 300, 400, 500]
# Suma de los elementos de la tupla: 1513.0
#
# Menú de opciones:
# 1. Sección de tuplas
# 2. Sección de diccionarios
# 3. Sección de excepciones
# 4. Sección de strings
# 5. Salir

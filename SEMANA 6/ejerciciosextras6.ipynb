# %% [markdown]
#  ## Ejercicios extras

# %% [markdown]
# ### BLOQUE 1 TEMAS 1 Y 2

# %% [markdown]
# ##### Ejercicio 1: Area de un triangulo

# %%
a = float(input("Ingresa la altura del triangulo en metros: "))
b = float(input("Ingresa la base del triangulo en metros: "))
area = (a * b) / 2
print("El area del triangulo es: ", area, "metros cuadrados")
# Out:
# El area del triangulo es:  132.0 metros cuadrados

# %% [markdown]
# ##### Ejercicio 2: Conversión de celsius a fahrenheit

# %%
celsius = float(input("Ingrese la temperatura en grados celsius: "))
f = celsius * 9/5 + 32
print(f"{celsius} grados celsius son igual a {f} grados fahrenheit")
# Out:
# 230.0 grados celsius son igual a 446.0 grados fahrenheit

# %% [markdown]
# ##### Ejercicio 3: Interes simple

# %%
cap = int(input("Ingrese el capital que desea que genere interes: "))
tasa = int(input("Ingrese la tasa de interes :"))
tiempo = int(input("Ingrese el tiempo que estara generando interes el capital:"))
interes = cap * (tasa/100) * tiempo
print("El interes simple es: ", interes)
# Out:
# El interes simple es:  900.0

# %% [markdown]
#  ### BLOQUE 2 TEMAS 3 Y 4.

# %% [markdown]
# ##### Ejercicio 4: Precendencia de operadores

# %%
total = 4 * 3 + 10 // 3 - 8 % 5 
print("4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 = ", total)
# Out:
# 4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 =  12

# %% [markdown]
# ##### Ejercicio 5

# %%
x = input("Ingresa un número: ")
print("x es tipo", type(x).__name__)
try:
    resultado = x + 1
except TypeError:
    print("Error: no se puede sumar un str con un int")
x = int(x)
resultado = x + 1
print("Resultado correcto:", resultado)
# Out:
# x es tipo str
# Error: no se puede sumar un str con un int
# Resultado correcto: 34

# %% [markdown]
# ##### Ejercicio 6: Conversión de horas a segundos

# %%
horas = float(input("Ingresa la cantidad de horas: "))
segundos = horas * 3600

print(f"{horas:g} horas equivalen a {segundos:g} segundos")
# Out:
# 22 horas equivalen a 79200 segundos

# %% [markdown]
# ##### Ejercicio 7: Descuentos con strings

# %%
precio = float(input("Ingresa el precio del artículo: $"))

descuento = precio * 0.15
precio_final = precio - descuento

print(f"Descuento (15%): ${descuento:.2f}")
print(f"Precio final: ${precio_final:.2f}")
# Out:
# Descuento (15%): $89.85
# Precio final: $509.15

# %% [markdown]
# ### BLOQUE 3 TEMAS 5, 6, 7 Y 8

# %% [markdown]
# ##### Ejercicio 8: Par o impar

# %%
num = int(input("ingrese un numero:"))
if num % 2 == 0:
    print(f"el numero {num} es par")
else:
    print(f"el numero {num} es impar")
# Out:
# el numero 55 es impar

# %% [markdown]
# ##### Ejercicio 9: numero mayor

# %%
numero1 = int(input("Dame un numero"))
numero2 = int(input("Dame un numero"))
numero3 = int(input("Dame un numero"))
if numero1 >= numero2 and numero1 >= numero3:
    print(f"El {numero1} es el mayor")
elif numero1 <= numero2 and numero2 >= numero3:
    print(f"El {numero2} es el mayor")
else:
    print(f"El {numero3} es el mayor")
# Out:
# El 7 es el mayor

# %% [markdown]
# ##### Ejercicio 10: Suma acumulada con while

# %%
suma = 0
numero = float(input("Ingresa un número (0 para terminar): "))

while numero != 0:
    suma += numero
    numero = float(input("Ingresa otro número (0 para terminar): "))

print(f"La suma acumulada es: {suma:g}")
# Out:
# La suma acumulada es: 8

# %% [markdown]
# ##### Ejercicio 11: Tabla de multiplicar con for

# %%
numero = int(input("Ingresa un número: "))

for i in range(1, 11):
    resultado = numero * i
    print(f"{numero} × {i} = {resultado}")
# Out:
# 11 × 1 = 11
# 11 × 2 = 22
# 11 × 3 = 33
# 11 × 4 = 44
# 11 × 5 = 55
# 11 × 6 = 66
# 11 × 7 = 77
# 11 × 8 = 88
# 11 × 9 = 99
# 11 × 10 = 110

# %% [markdown]
# ##### Ejercicio 12: suma de pares del 1 al 20

# %%
sum = 0

for numero in range(1, 21):
    if numero % 2 != 0:
        continue

    sum += numero

print(f"La suma de los numeros pares del 1 al 20 es: {sum}")
# Out:
# La suma de los numeros pares del 1 al 20 es: 110

# %% [markdown]
# ### BLOQUE 4 TEMAS DEL 9 AL 12

# %% [markdown]
# ##### Ejercicio 13: suma de una lista con funcion que regresa valor

# %%
def sumar_lista(lista):
    total = 0

    for numero in lista:
        total += numero

    return total


numeros = [10, 20, 30, 40, 50]

resultado = sumar_lista(numeros)

print(f"La suma de la lista es: {resultado}")
# Out:
# La suma de la lista es: 150

# %% [markdown]
# ##### Ejercicio 14: suma maxima

# %%
numeros = [7, 9, 11, 45, 67]
suma = 7 + 9 + 11 + 45 + 67

mayor = max(numeros)

print("La suma es:", suma)
print("El número máximo es:", mayor)
# Out:
# La suma es: 139
# El número máximo es: 67

# %% [markdown]
# ##### Ejercicio 15: Matriz y suma de primer diagonal

# %%
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

suma_diagonal = 0

for i in range(len(matriz)):
    suma_diagonal += matriz[i][i]

print("La suma de la diagonal principal es:", suma_diagonal)
# Out:
# La suma de la diagonal principal es: 15

# %% [markdown]
# ##### Ejercicio 16: promedio con funcion que no regresa valor

# %%
def calcular_promedio(notas):
    total = 0

    for nota in notas:
        total += nota

    promedio = total / len(notas)
    print(f"El promedio es: {promedio:.2f}")


calificaciones = [6, 7, 8]
calcular_promedio(calificaciones)
# Out:
# El promedio es: 7.00

# %% [markdown]
# ##### Ejercicio 17: invertir una lista con slicing

# %%
lista = [1, 2, 3, 4, 5]

lista_invertida = lista[::-1]

print("Lista invertida:", lista_invertida)
# Out:
# Lista invertida: [5, 4, 3, 2, 1]

# %% [markdown]
# ##### Ejercicio 18: Factorial con funcion recusiva

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)


numero = int(input("Ingresa un número entero no negativo: "))

if numero < 0:
    print("El factorial no está definido para números negativos.")
else:
    print(f"El factorial de {numero} es: {factorial(numero)}")
# Out:
# El factorial de 5 es: 120

# %% [markdown]
# ### BLOQUE 5 TEMAS DEL 13 AL 16

# %% [markdown]
# ##### Ejercicio 19 tupla acceso y suma con funcion

# %%
def sumar_tupla(tupla):
    return sum(tupla)


numeros = (28, 72, 22, 102, 74, 88)

print("El tercer elemento de la tupla es:", numeros[2])
print("La suma de la tupla es:", sumar_tupla(numeros))
# Out:
# El tercer elemento de la tupla es: 22
# La suma de la tupla es: 386

# %% [markdown]
# ##### Ejercicio 20: diccionario buscar contacto

# %%
def buscar_telefono(contactos, nombre):
    return contactos.get(nombre)
contactos = {
    "Raul" : "5612088786",
    "Wally" : "4423546798",
    "Anette" :"23211987890"
}
contacto_buscar = input("Ingrese el nombre del contacto que desea buscar: ")

telefono = buscar_telefono(contactos, contacto_buscar)

if telefono is not None:
    print(f"El teléfono de {contacto_buscar} es: {telefono}")
else:
    print("Contacto no encontrado.")
# Out:
# El teléfono de Raul es: 5612088786

# %% [markdown]
# ##### Ejercicio 21: diccionario de calificaciones y promedios

# %%
def buscar_nombre(nombre, calif):
    return calif.get(nombre)
def buscar_notas(num, calif):
    return calif.get(num)

calif = {
    "ana" : [9, 8, 10],
    "beto" : [10, 8, 8]
}
for nombre in calif:
    total = 0
    for notas in calif[nombre]:
        total += notas
    promedio = total / len(calif[nombre])
    print(f"{nombre}: promedio {promedio:.2f}")
# Out:
# ana: promedio 9.00
# beto: promedio 8.67

# %% [markdown]
# ##### Ejercicio 22: Excepcion de un valor no numerico

# %%
try:
    numero = float(input("Ingresa un número: "))
except ValueError:
    print("Error: debes ingresar un valor numérico")
# Out:
# Error: debes ingresar un valor numérico

# %% [markdown]
# ##### Ejercicio 23:  excepcion de division entre 0

# %%
try:
    numerador = float(input("Ingresa el numerador: "))
    denominador = float(input("Ingresa el denominador: "))

    resultado = numerador / denominador
    print("El resultado es:", resultado)

except ZeroDivisionError:
    print("Error: no se puede dividir entre cero.")

except ValueError:
    print("Error: debes ingresar un valor numérico.")
# Out:
# Error: no se puede dividir entre cero.

# %% [markdown]
# ##### Ejercicio 24 : contar palabras con un string

# %%
def contar_palabras(texto):
    palabras = texto.split()
    return len(palabras)


mensaje = "Python es un lenguaje de progrtamacion"

print("Longitud del mensaje:", len(mensaje))
total_palabras = contar_palabras(mensaje)
print("Palabras totales:", total_palabras)
# Out:
# Longitud del mensaje: 38
# Palabras totales: 6

# %% [markdown]
# ##### Ejercicio 25: contar palabras remplazar y mayusculas

# %%
def contar_palabras(texto):
    palabras = texto.split()
    return len(palabras)


mensaje = "Taylor swift es la mejor cantante de todos los tiempos"

print("Longitud del mensaje:", len(mensaje))
total_palabras = contar_palabras(mensaje)
print("Palabras totales:", total_palabras)
print("En mayúsculas:", mensaje.upper())
texto_reemplazado = mensaje.replace("Taylor swift", "North west")
print("Texto reemplazado:", texto_reemplazado)
# Out:
# Longitud del mensaje: 54
# Palabras totales: 10
# En mayúsculas: TAYLOR SWIFT ES LA MEJOR CANTANTE DE TODOS LOS TIEMPOS
# Texto reemplazado: North west es la mejor cantante de todos los tiempos

# %% [markdown]
# # BLOQUE 2. DECISIONES,ENTRADAS Y SALIDAS

# %%
calificacion = float(input("Ingresa tu calificacion del semestre:"))
if calificacion >= 9:
    print("Tu calificacion es: A")
elif calificacion >= 8:
    print("Tu calificacion es: B")
elif calificacion >= 7:
    print("Tu calificacion es: C")
elif cailificacion >= 6:
    print("Tu calificacion es: D")
else:
    print("Tu calificacion es: F")
# Out:
# Tu calificacion es: A

# %%
numero = float(input("Ingrese un numero entero"))
if numero % 2 == 0:
    print("Es numero par")
else:
    print("Es numero impar")
# Out:
# Es numero par

# %%
numero1 = int(input("Dame un numero"))
numero2 = int(input("Dame un numero"))
numero3 = int(input("Dame un numero"))
if numero1 >= numero2 and numero1 >= numero3:
    print(f"El {numero1} es el mayor")
elif numero1 <= numero2 and numero2 >= numero3:
    print(f"El {numero2} es el mayor")
else:
    print(f"El {numero3} es el mayor")
# Out:
# El 15 es el mayor

# %%
suma = 0

while True:
    num = int(input("Ingresa un valor(Ingresa 0 para terminar)"))
    if num == 0:
        break 
    suma += num
print(f"La suma de los valores es {suma}")
# Out:
# La suma de los valores es 317

# %% [markdown]
# # Semana 1

# %%
print("Hola")
# Out:
# Hola

# %%
 name = "sophia"
 edad = 17 
 estatura = 1.64
 es_estudiante = True

# %%
print("mi nombre es" , name)
# Out:
# mi nombre es sophia

# %%
print("este print es un cambio")
# Out:
# este print es un cambio

# %%
distancia = float(input("Ingrese la distancia en kilometros: "))
tiempo = float(input("Ingrese el tiempo en horas: "))

print (" El dato distancia es de tipo: " , type(distancia))
print (" El dato tiempo es de tipo: " , type(tiempo))

velocidad = distancia / tiempo
print ("la velocidad es: " , velocidad, "km/h")
# Out:
#  El dato distancia es de tipo:  <class 'float'>
#  El dato tiempo es de tipo:  <class 'float'>
# la velocidad es:  2.0 km/h

# %%
a = 5
b = 2

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
print(a < b)
print(a > b)
print(a == b)
print(a != b)
print(a <= b)
print(a >= b)
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 1
# 25
# False
# True
# False
# True
# False
# True

# %%
nombre = input("Ingrese su nombre: ")

edad = (input("Ingrese su edad: "))

print("Hola", nombre, "bienvenido a la clase de fundamentos, tienes", edad, "años")
# Out:
# Hola alberto bienvenido a la clase de fundamentos, tienes 22 años

# %% [markdown]
# tema 4

# %%
edad_str = input("Ingrese su edad: ")
print(type(edad_str)) # <class 'str'>
# Out:
# <class 'str'>

# %%
edad = int(edad_str) # conversion a número entero
proximo_ano = edad + 1
print (f"El próximo año tendrás {proximo_ano} años")
# Out:
# El próximo año tendrás 19 años

# %%
precio = float(input("Ingrese el precio del producto: "))
descuento = precio * 0.20
precio_final = precio - descuento 
print(f"Precio final con 20% de descuento: ${precio_final:.2f}")
# Out:
# Precio final con 20% de descuento: $15679.20

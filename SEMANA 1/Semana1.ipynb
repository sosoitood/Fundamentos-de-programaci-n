# %% [markdown]
# # Semana 1

# %%
print("Hola")
# Out:
# Hola

# %%
 name = "sophia"
 edad = 17 
 estatura = 1.64
 es_estudiante = True

# %%
print("mi nombre es" , name)
# Out:
# mi nombre es sophia
